# %%
import tensorflow as tf

# Sample Inputs
sentences = [
    'i love my dog',
    'I, love my cat'
]

# Initialize the layer
vectorize_layer = tf.keras.layers.TextVectorization()

#Build the vocalbury
vectorize_layer.adapt(sentences)

vocabulary = vectorize_layer.get_vocabulary(include_special_tokens = False)
# Out:
# 2026-03-10 05:46:19.602303: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773121579.892067      17 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773121579.976107      17 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773121580.661734      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773121580.661810      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773121580.661814      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773121580.661817      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-10 05:46:54.537197: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
for i,word in enumerate(vocabulary):
    print(i,word)
# Out:
# 0 my
# 1 love
# 2 i
# 3 dog
# 4 cat

# %%
# Add another input
sentences = [
    'i love my dog',
    'I, love my cat',
    'You love my dog!'
]

# Initialize the layer
vectorize_layer = tf.keras.layers.TextVectorization()

# Build the vocabulary
vectorize_layer.adapt(sentences)

# Get the vocabulary list. Ignore special tokens for now.
vocabulary = vectorize_layer.get_vocabulary(include_special_tokens=False)

# %%
# Print the token index
for index, word in enumerate(vocabulary):
  print(index, word)
# Out:
# 0 my
# 1 love
# 2 i
# 3 dog
# 4 you
# 5 cat

# %%
# Get the vocabulary list.
vocabulary = vectorize_layer.get_vocabulary()

# Print the token index
for index, word in enumerate(vocabulary):
  print(index, word)
# Out:
# 0
# 1 [UNK]
# 2 my
# 3 love
# 4 i
# 5 dog
# 6 you
# 7 cat
